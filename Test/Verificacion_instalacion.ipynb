# %%
# ============================================
# 1. VERIFICAR ENTORNO BÁSICO
# ============================================
import sys
print(f"Python: {sys.version}")
print(f"Python path: {sys.executable}")
# Out:
# Python: 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0]
# Python path: /opt/conda/bin/python

# %%
# ============================================
# 2. NUMPY Y PANDAS
# ============================================
import numpy as np
import pandas as pd
arr = np.array([1, 2, 3, 4, 5])
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
print(f"\nNumPy: {np.__version__}")
print(f"Array test: {arr * 2}")
print(f"\nPandas: {pd.__version__}")
print(df.head())
# Out:
# NumPy: 1.26.4
# Array test: [ 2  4  6  8 10]
#
# Pandas: 2.1.1
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# ============================================
# 3. MATPLOTLIB
# ============================================
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r-o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Test Matplotlib')
plt.show()
print(f"Matplotlib: {plt.matplotlib.__version__}")
# Out:
# Matplotlib: 3.8.0

# %%
# ============================================
# 4. SCIKIT-LEARN
# ============================================
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=100, n_features=4, random_state=42)
clf = RandomForestClassifier(n_estimators=10, random_state=42)
clf.fit(X, y)
print(f"\nscikit-learn: {sklearn.__version__}")
print(f"Accuracy: {clf.score(X, y):.2f}")
# Out:
# scikit-learn: 1.3.1
# Accuracy: 0.99

# %%
# ============================================
# 5. TENSORFLOW
# ============================================
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(tf.config.list_physical_devices('GPU'), 'GPU')

print(f"\nTensorFlow: {tf.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")
# Simple operation
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([[5, 6], [7, 8]])
result = tf.matmul(a, b)
print(f"Matrix multiply:\n{result.numpy()}")
# Out:
# TensorFlow: 2.21.0
# GPU available: []
# Matrix multiply:
# [[19 22]
#  [43 50]]

# %%
# ============================================
# 6. KERAS
# ============================================
import keras
print(f"\nKeras: {keras.__version__}")
# Out:
# Keras: 3.14.0

# %%
# ============================================
# 7. PYTORCH
# ============================================
import torch
print(f"\nPyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU count: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Simple tensor operation
x = torch.randn(3, 3)
y = torch.randn(3, 3)
z = x @ y
print(f"PyTorch tensor operation OK")
# Out:
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU count: 2
# GPU 0: NVIDIA GeForce RTX 4070 SUPER
# GPU 1: NVIDIA GeForce RTX 5080
# PyTorch tensor operation OK

# %%
# ============================================
# 8. TRANSFORMERS
# ============================================
import transformers
from transformers import pipeline
print(f"\nTransformers: {transformers.__version__}")
# Out:
# Transformers: 5.6.2

# %%
# ============================================
# 9. VERIFICAR GPU CON PYTORCH
# ============================================
import torch
if torch.cuda.is_available():
    print(f"\n=== GPU TEST ===")
    print(f"Device: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    print(f"Device: {torch.cuda.get_device_name(1)}")
    print(f"Memory: {torch.cuda.get_device_properties(1).total_memory / 1e9:.1f} GB")
    # Test compute
    x = torch.randn(1000, 1000).cuda()
    y = torch.randn(1000, 1000).cuda()
    z = x @ y
    print("GPU computation: OK")
else:
    print("\nGPU not available")
# Out:
# === GPU TEST ===
# Device: NVIDIA GeForce RTX 4070 SUPER
# Memory: 12.9 GB
# Device: NVIDIA GeForce RTX 5080
# Memory: 17.1 GB
# GPU computation: OK
